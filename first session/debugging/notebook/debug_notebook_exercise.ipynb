# %% [markdown]
# # Notebook Debugging Exercise
#
# This notebook is part of Exercise 10.
#
# Use breakpoints in both notebook cells and `src/exercise10_threshold.py` to debug function calls across files.

# %%
from pathlib import Path

from src.exercise10_threshold import (
    load_probabilities_from_csv,
    predictions_from_probabilities,
)

# %%
data_file: Path = Path.cwd().parent / "data" / "model_scores.csv"
probabilities: list[float] = load_probabilities_from_csv(str(data_file))
probabilities

# %%
threshold: float = 0.5
predictions: list[int] = predictions_from_probabilities(probabilities, threshold)
predictions

# %%
expected_predictions: list[int] = [1, 1, 1, 0, 0, 1]
assert predictions == expected_predictions

# %% [markdown]
# ## Student task
#
# Use debugging tools to identify why the assertion fails and make the implementation satisfy the expected behavior.
